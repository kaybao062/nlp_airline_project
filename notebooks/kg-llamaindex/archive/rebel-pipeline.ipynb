# %% [markdown]
# Using REBEL model to extract entities and relationships instead of LLM.
#
# Follow along: https://colab.research.google.com/drive/1G6pcR0pXvSkdMQlAK_P-IrYgo-_staxd?usp=sharing#scrollTo=XX_GxhusPZR8
#
# Install Nebula Graph: `curl -fsSL nebula-up.siwei.io/install.sh | bash`
#
# Also follow along: https://colab.research.google.com/drive/1tLjOg2ZQuIClfuWrAC2LdiZHCov8oUbs#scrollTo=kkHpLzEuYo_9

# %%
import os

import openai
import pandas as pd
from dotenv import load_dotenv
from transformers import pipeline
from llama_index.core import (
    Document,
    KnowledgeGraphIndex,
    StorageContext,
)
from llama_index.core.settings import Settings
from llama_index.core.text_splitter import SentenceSplitter
from llama_index.llms.openai import OpenAI
from llama_index.graph_stores.nebula import NebulaGraphStore

load_dotenv()

openai.api_key = os.environ["OPENAI_API_KEY"]

os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %% [markdown]
# Setup nebula graph:
#
# Run ngql:
# ```CREATE SPACE llamaindex(vid_type=FIXED_STRING(256), partition_num=1, replica_factor=1);
# USE llamaindex;
# CREATE TAG entity(name string);
# CREATE EDGE relationship(relationship string);
# CREATE TAG INDEX entity_index ON entity(name(256));
# ```

# %%
space_name = "llamaindex"
edge_types, rel_prop_names = ["relationship"], [
    "relationship"
]  # default, could be omit if create from an empty kg
tags = ["entity"]  # default, could be omit if create from an empty kg

graph_store = NebulaGraphStore(
    space_name=space_name,
    edge_types=edge_types,
    rel_prop_names=rel_prop_names,
    tags=tags,
)
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %% [markdown]
# Load review documents:

# %%
def load_reviews(
    file: str = "../../data/clean/cleaned_reviews.csv",
    start_index: int = 0,
    limit: int = 10,
):
    df = pd.read_csv(file)[start_index:start_index + limit]
    print(f"Loaded reviews: {df.shape}")
    df["Content"] = df.apply(lambda row: f"{row['Review Title']}\n{row['Review Content']}", axis=1)

    documents = [
        Document(
            text=row["Content"],
            metadata={
                "Airline": row["Airline"],
                "Type of Traveller": row["Type of Traveller"],
                "Route": row["Route"],
                "Class": row["Class"],
                "Month Flown": row["Month Flown"],
                "Review Date": row["Review Date"],
            }
        )
        for _, row in df.iterrows()
    ]
    return documents
    # splitter = SentenceSplitter(
    #    chunk_size=200,
    #    chunk_overlap=0,
    #    paragraph_separator="\n\n"
    #)
    # 
    #nodes = splitter.get_nodes_from_documents(documents)
    # return nodes

# %%
reviews = load_reviews(limit=1_0000_000)
len([doc for doc in reviews if "American" in doc.metadata["Airline"]])
# Out:
# Loaded reviews: (28950, 15)
# [Document(id_='c1947939-44c2-4028-998d-958fb002a6a6', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Dallas Ft Worth to Austin', 'Class': 'Economy Class', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-21'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Never fly with them\nI'm writing this for my wife. She has been stranded by American for 18 hours now, and counting. Two cancellations, and then delays. The plane she's waiting on now was late leaving Austin, and is delayed about 3 hours so far. We have to decide if she's just going to a hotel, and I have to drive to Dallas to pick her up. We are about to give up on the idea of American getting her out of DFW at all. We haven't even begun to talk to them about a refund, but I can imagine how that's going to go. Terrible company. Never fly with them. They have tortured her. She's been awake at the airport for 18 hours now, and she is overwhelmed with exhaustion. Don't let this happen to you. Don't fly American.", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='91e79e6e-6672-4b72-87d0-601a4f73805f', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Dallas to Philadelphia', 'Class': 'Economy Class', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-21'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text
start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='86bbecfd-5acc-4189-9b54-6c30ecde2572', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Family Leisure', 'Route': 'Miami to San Diego', 'Class': 'Economy Class', 'Month Flown': '2022-05-01', 'Review Date': '2022-05-24'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Shame on you American Airlines\nOur flight out of Key West to Sacramento was cancelled on our way to the airport. When I called she acted like well all we have is in a couple days take it or leave it. We have no accommodations in Key West. Where are we supposed to sleep, at the airport. These airlines do not care if you are stranded cause they don’t have a full plane and then they blame it on weather. Our hotel was very close to the airport and planes were landing and taking off all morning. Shame on you American Airlines. You can take my advantage number and shove it cause I won’t be on another AA flight ever again.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9391f88b-9b24-47f1-831b-c1776fc9fbad', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Couple Leisure', 'Route': 'Miami to San Diego via Dallas', 'Class': 'Economy Class', 'Month Flown': '2022-05-01', 'Review Date': '2022-05-24'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='They lost us as customers\nOur flight was canceled and then rescheduled for the next day, which meant we had to book a last-minute hotel and stay on our trip an extra day, incurring extra expenses of a few hundred dollars. AA offered no apology, and when I asked to have even just a complimentary seat change, they wouldn’t even do that. They lost us as customers.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='03f0f9d5-c625-4da2-98e8-d9000e607455', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Couple Leisure', 'Route': 'Norfolk to Cleveland', 'Class': 'Economy Class', 'Month Flown': '2022-05-01', 'Review Date': '2022-05-24'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='role models for the service industry\nOur flight was really messed up due to my husband not knowing how to work computers. The attendants at the service desk (Sandy, Sarah and Gwen) had the patience of an angel. They took their time to fix the problem, to make sure we got our refund back. And they also made sure that they got us on the next flight out tomorrow with seats sitting next to each other. Due to me mentioning that I’m afraid to fly. These woman were very kind, had so much patience and very understanding with the lack of our knowledge with computers. American Airlines is lucky to have them. It wasn’t an easy fix but they joked and laughed with us and before we knew it our flights were rescheduled the next day. They are role models for the service industry.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d497cf0e-e6f3-433a-9d35-8aa8fcdb513f', embedding=None, metadata={'Airline': 'American Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Madrid to Calgary via Dallas / Chicago', 'Class': 'Economy Class', 'Month Flown': '2022-04-01', 'Review Date': '2022-05-22'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="the worst airline ever\nDallas to Cancun via Newark. This is the worst airline ever. I was waiting at Dallas airport waiting for my flight when there were 7 delays. The first delay was because the plane wasn't here yet. The second delay was that the hanger had a big problem. The third delay was that it was the same situation. The Fourth, Fifth, and Sixth delay was the same. Finally, the plane arrived at the airport. We got on the plane and there was a super long line. It took forever to call from group to group. I was in group 9. In the middle of the flight, They served food and beverage which was fine right before we were landing, they ran out of choices.", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ...]

# %% [markdown]
# Load extract triplets functions:

# %%
# Function to parse the generated text and extract the triplets
# Rebel outputs a specific format. This code is mostly copied from the model card!

triplet_extractor = pipeline(
    "text2text-generation",
    model="Babelscape/rebel-large",
    tokenizer="Babelscape/rebel-large",
    device=-1,
    temperature=0.3,
    top_p=0.2,
    # do_sample=True,
) # , device="cuda:0")


def extract_triplets(input_text):
    text = triplet_extractor.tokenizer.batch_decode([triplet_extractor(input_text, return_tensors=True, return_text=False)[0]["generated_token_ids"]])[0]

    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and subject in input_text and relation != '' and relation in input_text and object_ != '' and object_ in input_text:
        triplets.append((subject.strip(), relation.strip(), object_.strip()))

    return triplets
# Out:
# /Users/pez/.local/share/virtualenvs/nlp_airline_project-fCxuAmfF/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
print(reviews[2].text)
# Out:
# Crew was super nice
# Flight was great! Crew was super nice, Chief Stewardess & FSS showered me with many snacks! And one of the FSS gave me a bag tag, offered to take my picture, and had a little talk. She was so kind and fun. The food was delicious. Booked BTC (The burger & Steak), burger was amazing, chefs kiss. What The steak was a little over cooked but that’s okay, the sides were delicious. The seat was clean, as well as the bathroom. IFE had many movies, shows, music to choose from. Seat could transform to a full flat bed, inflight wifi could be used for instagram, WhatsApp, etc. Crew tried to keep me entertained at every moment, offering me such things as snacks, toys etc. Love Singapore Airlines. The world class service is wonderful. Check in experience with LHR was good but not amazing, girl who checked me in looks rather annoyed. Lounge was great, gave me a free lion teddy.

# %%
triplet_extractor.tokenizer.batch_decode([triplet_extractor(reviews[2].text, return_tensors=True, return_text=False)[0]["generated_token_ids"]])
# Out:
# /Users/pez/.local/share/virtualenvs/nlp_airline_project-fCxuAmfF/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.3` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /Users/pez/.local/share/virtualenvs/nlp_airline_project-fCxuAmfF/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.2` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# ['<s><triplet> IFE <subj> Singapore Airlines <obj> owned by</s>']

# %%
extract_triplets(reviews[2].text)
# Out:
# []

# %%
input_sentence = "Gràcia is a district of the city of Barcelona, Spain. It comprises the neighborhoods of Vila de Gràcia, Vallcarca i els Penitents, El Coll, La Salut and Camp d'en Grassot i Gràcia Nova. Gràcia is bordered by the districts of Eixample to the south, Sarrià-Sant Gervasi to the west and Horta-Guinardó to the east. A vibrant and diverse enclave of Catalan life, Gràcia was an independent municipality for centuries before being formally annexed by Barcelona in 1897 as a part of the city's expansion."
extract_triplets(input_sentence)
# Out:
# []

# %%
import spacy
import spacy_components

nlp = spacy.load("en_core_web_sm")

nlp.add_pipe("rebel", after="senter", config={
    'device':0, # Number of the GPU, -1 if want to use CPU
    'model_name':'Babelscape/rebel-large'} # Model used, will default to 'Babelscape/rebel-large' if not given
    )
input_sentence = "Gràcia is a district of the city of Barcelona, Spain. It comprises the neighborhoods of Vila de Gràcia, Vallcarca i els Penitents, El Coll, La Salut and Camp d'en Grassot i Gràcia Nova. Gràcia is bordered by the districts of Eixample to the south, Sarrià-Sant Gervasi to the west and Horta-Guinardó to the east. A vibrant and diverse enclave of Catalan life, Gràcia was an independent municipality for centuries before being formally annexed by Barcelona in 1897 as a part of the city's expansion."
                 
doc = nlp(input_sentence)
doc_list = nlp.pipe([input_sentence])
for value, rel_dict in doc._.rel.items():
    print(f"{value}: {rel_dict}")
# Out:
# /Users/pez/.local/share/virtualenvs/nlp_airline_project-fCxuAmfF/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/pez/.local/share/virtualenvs/nlp_airline_project-fCxuAmfF/lib/python3.11/site-packages/transformers/generation/beam_search.py:377: UserWarning: MPS: no support for int64 for min_max, downcasting to a smaller data type (int32/float32). Native support for int64 has been added in macOS 13.3. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/ReduceOps.mm:612.)
#   sent_lengths_max = sent_lengths.max().item() + 1
# (0, 8): {'relation': 'located in the administrative territorial entity', 'head_span': Gràcia, 'tail_span': Barcelona}
# (0, 10): {'relation': 'country', 'head_span': Gràcia, 'tail_span': Spain}
# (8, 0): {'relation': 'contains administrative territorial entity', 'head_span': Barcelona, 'tail_span': Gràcia}
# (8, 10): {'relation': 'country', 'head_span': Barcelona, 'tail_span': Spain}
# (17, 0): {'relation': 'located in the administrative territorial entity', 'head_span': Vila de Gràcia, 'tail_span': Gràcia}
# (21, 0): {'relation': 'located in the administrative territorial entity', 'head_span': Vallcarca i els Penitents, 'tail_span': Gràcia}
# (26, 0): {'relation': 'located in the administrative territorial entity', 'head_span': El Coll, 'tail_span': Gràcia}
# (29, 0): {'relation': 'located in the administrative territorial entity', 'head_span': La Salut, 'tail_span': Gràcia}
# (0, 46): {'relation': 'shares border with', 'head_span': Gràcia, 'tail_span': Eixample}
# (0, 51): {'relation': 'shares border with', 'head_span': Gràcia, 'tail_span': Sarrià-Sant Gervasi}
# (0, 59): {'relation': 'shares border with', 'head_span': Gràcia, 'tail_span': Horta-Guinardó}
# (46, 0): {'relation': 'shares border with', 'head_span': Eixample, 'tail_span': Gràcia}
# (46, 51): {'relation': 'shares border with', 'head_span': Eixample, 'tail_span': Sarrià-Sant Gervasi}
# (51, 0): {'relation': 'shares border with', 'head_span': Sarrià-Sant Gervasi, 'tail_span': Gràcia}
# (51, 46): {'relation': 'shares border with', 'head_span': Sarrià-Sant Gervasi, 'tail_span': Eixample}
# (51, 59): {'relation': 'shares border with', 'head_span': Sarrià-Sant Gervasi, 'tail_span': Horta-Guinardó}

# %%
doc = nlp(reviews[2].text)
doc_list = nlp.pipe([reviews[2].text])
for value, rel_dict in doc._.rel.items():
    print(f"{value}: {rel_dict}")
# Out:
# (0, 5): {'relation': 'part of', 'head_span': Crew, 'tail_span': Flight}
# (5, 0): {'relation': 'has part', 'head_span': Flight, 'tail_span': Crew}
# (63, 65): {'relation': 'has part', 'head_span': burger, 'tail_span': Steak}
# (65, 63): {'relation': 'part of', 'head_span': Steak, 'tail_span': burger}
# (89, 65): {'relation': 'has part', 'head_span': sides, 'tail_span': Steak}
# (94, 102): {'relation': 'part of', 'head_span': seat, 'tail_span': bathroom}
# (102, 94): {'relation': 'has part', 'head_span': bathroom, 'tail_span': seat}
# (107, 109): {'relation': 'has part', 'head_span': movies, 'tail_span': shows}
# (109, 107): {'relation': 'part of', 'head_span': shows, 'tail_span': movies}
# (131, 126): {'relation': 'uses', 'head_span': instagram, 'tail_span': wifi}
# (133, 126): {'relation': 'uses', 'head_span': WhatsApp, 'tail_span': wifi}
# (22, 142): {'relation': 'use', 'head_span': snacks, 'tail_span': entertained}
# (157, 158): {'relation': 'facet of', 'head_span': Love Singapore Airlines, 'tail_span': Singapore Airlines}
# (172, 168): {'relation': 'has part', 'head_span': LHR, 'tail_span': Check in}
# (168, 172): {'relation': 'part of', 'head_span': Check in, 'tail_span': LHR}
# (196, 197): {'relation': 'subclass of', 'head_span': lion, 'tail_span': teddy}

# %%
reviews = load_reviews()

for review in reviews:
    print(f"Review: {review}")
    triplets = extract_triplets(review.text)
    print(f"Triplets: {triplets}")
    print("--")
# Out:
# Loaded reviews: (10, 15)
# Review: Doc ID: 0c5f635e-f9a5-4104-8e64-4f1ef481dc60
# Text: Food was below par Overall disappointing from Singapore
# Airlines. Late and disorganized boarding. The A350-900 is a tired old
# thing. Does anyone seriously use the coat hanger button on the seat
# back in front of you? This aircraft has no air outlets above seats and
# made the trip stuffy. The entertainment system was very old and dated
# movies, yes ...
# Triplets: []
# --
# Review: Doc ID: d8e0b688-d012-4295-8fac-b2793fb74a12
# Text: recent pricing and service changes I usually fly Singapore
# Airlines internationally, since 10 years I am a Krisflyer Gold member.
# The recent pricing and service changes, show the results of bailed out
# airlines believing ethical standards don't apply to them anymore.
# Unbelievably toxic SIA service for business customers. Bear in mind if
# you fly f...
# Triplets: []
# --
# Review: Doc ID: f9c95404-7944-46a4-9436-a98b69a02bf7
# Text: Crew was super nice Flight was great! Crew was super nice, Chief
# Stewardess & FSS showered me with many snacks! And one of the FSS gave
# me a bag tag, offered to take my picture, and had a little talk. She
# was so kind and fun. The food was delicious. Booked BTC (The burger &
# Steak), burger was amazing, chefs kiss. What The steak was a little
# over...
# Triplets: []
# --
# Review: Doc ID: 67698848-449d-4e05-a22a-27d5239a5cf7
# Text: attendants are helpful and polite The cabin is clean. Flight
# attendants are helpful and polite. Seats can be reclined easily. The
# food is delicious and fresh. Flights departed on time.
# Triplets: []
# --
# Review: Doc ID: e0a0c42e-edac-433e-8d2a-07fb9cb464ce
# Text: food were served last From Kochi to Singapore and vice verse we
# travelled in economy class and we opted for extra legroom seats. The
# seats were in the middle of the aircraft and food were served last for
# us. Both times the non-veg food (chicken) got finished and we were had
# to eat veg food.
# Triplets: []
# --
# Review: Doc ID: 286fe110-dc60-4a74-9b7d-cbc23995b89b
# Text: seat spacing is less The flight went from Terminal 1, the
# terminal with limited amenities. I was handed a voucher to a Sats
# lounge that was overfilled in terminal 1. The gate was chaos, under-
# dimensioned for the flight with 1 security screening. When I arrived
# the queue was >50m with a wait of about 20min. While service and
# entertainment in Econ...
# Triplets: []
# --
# Review: Doc ID: 2ad402a9-2a1e-498d-ae74-f6c0c3e4a4ff
# Text: service was efficient and friendly SQ894 is the afternoon flight
# to HKG operated by the A350. It was during the Lunar New Year period.
# On the menu was the traditional Yu Sheng or raw fish salad popular in
# Singapore and Malaysia during Lunar New Year. I booked the cook and
# had lobster thermidor as my main course. For a 3.5 hour flight the
# service...
# Triplets: []
# --
# Review: Doc ID: c9d5d90c-0729-405a-a3e8-0b0b85e5a706
# Text: “Very disappointed” Very disappointed with Singapore Airlines.
# Dated and uncomfortable old seat in business class combined with below
# average food. Ok cabin crews. Last but not least they lost my bag. I
# would fly SQ again on short haul on a discount economy class ticket…
# Triplets: []
# --
# Review: Doc ID: fbfa691b-3831-406b-9e36-3f12f4e55c42
# Text: incompetent customer service I was flying business class from
# BCN to MLE via SIN. The flight with SQ was just a big hassle all the
# way through. The night before the BCN departure I was informed via SMS
# that the flight from BCN to SIN would be delayed by more that 3 hours.
# That was it. SQ could not have cared less about re-booking the flight
# proa...
# Triplets: []
# --
# Review: Doc ID: 1fc35f90-d414-4976-8364-c4fb16820a6c
# Text: not be flying Singapore Airlines again Singapore Airlines
# continues to enjoy a good reputation, however my most recent
# experience was very poor and fell far short of my expectations. Due to
# a cancellation by another airline, I needed to modify the departure on
# my full fare, refundable ticket. I completed the customer assistance
# form on their web...
# Triplets: []
# --

# %% [markdown]
# Load Graph Index Query Engine:

# %%
Settings.llm = OpenAI(model="gpt-3.5-turbo")
Settings.chunk_size = 256
# Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
# Settings.node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=20)
# Settings.num_output = 512
# Settings.context_window = 3900

documents = load_reviews()
# index = KnowledgeGraphIndex.from_documents(documents, kg_triplet_extract_fn=extract_triplets)
index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=10,
    space_name=space_name,
    edge_types=edge_types,
    rel_prop_names=rel_prop_names,
    tags=tags,
    include_embeddings=True,
    # kg_triplet_extract_fn=extract_triplets,
)
# Out:
# Loaded reviews: (10, 15)

# %% [markdown]
# Check it was loaded to Nebula:

# %%
# %load_ext ngql
# %ngql --address 127.0.0.1 --port 9669 --user root --password nebula
# Out:
# Connection Pool Created
#          Name
# 0  llamaindex

# %%
# %ngql USE llamaindex;
# %ngql MATCH ()-[e]->() RETURN e LIMIT 100;
# Out:
#                                                     e
# 0   ("2024-04-21")-[:relationship@8324040960810900...
# 1   ("Chief stewardess")-[:relationship@-717721805...
# 2   ("2024-04-01")-[:relationship@-707808986102225...
# 3   ("2024-04-01")-[:relationship@2576048185196685...
# 4   ("2024-04-01")-[:relationship@6481582437030897...
# ..                                                ...
# 95  ("Singapore airlines")-[:relationship@40560834...
# 96  ("Singapore airlines")-[:relationship@40560834...
# 97  ("Singapore airlines")-[:relationship@40560834...
# 98  ("Singapore airlines")-[:relationship@44683897...
# 99  ("Singapore airlines")-[:relationship@47820293...
#
# [100 rows x 1 columns]

# %%
documents[0].text
# Out:
# 'Food was below par\nOverall disappointing from Singapore Airlines. Late and disorganized boarding. The A350-900 is a tired old thing. Does anyone seriously use the coat hanger button on the seat back in front of you? This aircraft has no air outlets above seats and made the trip stuffy. The entertainment system was very old and dated movies, yes even the so called “recent releases”. TV selections were abysmal.  This was the first international flight I watched nothing at all on. Food was below par and drinks service patchy. I used to think Singapore Airlines was a great airline but after this flight I beg to differ. One good point is the staff on board professional and friendly.'

# %%
for r in reviews:
    print(r.metadata)
    print(r.text)
# Out:
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Couple Leisure', 'Route': 'Melbourne to Singapore', 'Class': 'Economy Class', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-21'}
# Food was below par
# Overall disappointing from Singapore Airlines. Late and disorganized boarding. The A350-900 is a tired old thing. Does anyone seriously use the coat hanger button on the seat back in front of you? This aircraft has no air outlets above seats and made the trip stuffy. The entertainment system was very old and dated movies, yes even the so called “recent releases”. TV selections were abysmal.  This was the first international flight I watched nothing at all on. Food was below par and drinks service patchy. I used to think Singapore Airlines was a great airline but after this flight I beg to differ. One good point is the staff on board professional and friendly.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Business', 'Route': 'Zurich to Singapore', 'Class': 'Premium Economy', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-21'}
# recent pricing and service changes
# I usually fly Singapore Airlines internationally, since 10 years I am a Krisflyer Gold member. The recent pricing and service changes, show the results of bailed out airlines believing ethical standards don't apply to them anymore. Unbelievably toxic SIA service for business customers. Bear in mind if you fly for business and may have changes you will need 3 days and potentially dozens of phone calls and sessions to even rebook flexi tickets which then costs north of 1000$. This particular flight was booked via our company travel agent, a large international agent. Leaving aside the drop in service quality over years, from discontinuing warm towels to not offering snacks anymore during the flight, what has really infuriated me with SIA are the change policies. On this flight, despite having the highest premium economy booking class (T) with a full flexi ticket, a simple change in flight date cost me >1000$ extra is unexplained fees: In addition to the change in ticket price, which makes no sense on the highest booking class, a rebooking fee, a no show fee , a digital processing fee and the worst 250$ of "offline" fee because I used an agent, not their website. While my agent was helpful, SIA straight out refused to talk to them. It took 3 full days and 15 chat sessions to actually get the ticket rebooked for a simple day change on the exact same flight, SIA let them wait 30min per session, as they are only available to agents during Singapore business hours - and if they are closes they simply hang up.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'London to Singapore', 'Class': 'Business Class', 'Month Flown': '2024-01-01', 'Review Date': '2024-04-14'}
# Crew was super nice
# Flight was great! Crew was super nice, Chief Stewardess & FSS showered me with many snacks! And one of the FSS gave me a bag tag, offered to take my picture, and had a little talk. She was so kind and fun. The food was delicious. Booked BTC (The burger & Steak), burger was amazing, chefs kiss. What The steak was a little over cooked but that’s okay, the sides were delicious. The seat was clean, as well as the bathroom. IFE had many movies, shows, music to choose from. Seat could transform to a full flat bed, inflight wifi could be used for instagram, WhatsApp, etc. Crew tried to keep me entertained at every moment, offering me such things as snacks, toys etc. Love Singapore Airlines. The world class service is wonderful. Check in experience with LHR was good but not amazing, girl who checked me in looks rather annoyed. Lounge was great, gave me a free lion teddy.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Taipei to Singapore', 'Class': 'Economy Class', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-13'}
# attendants are helpful and polite
# The cabin is clean. Flight attendants are helpful and polite. Seats can be reclined easily. The food is delicious and fresh. Flights departed on time.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Couple Leisure', 'Route': 'Kochi to Singapore', 'Class': 'Economy Class', 'Month Flown': '2024-04-01', 'Review Date': '2024-04-12'}
# food were served last
# From Kochi to Singapore and vice verse we travelled in economy class and we opted for extra legroom seats. The seats were in the middle of the aircraft and food were served last for us. Both times the non-veg food (chicken) got finished and we were had to eat veg food.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Business', 'Route': 'Singapore to Sydney', 'Class': 'Economy Class', 'Month Flown': '2024-02-01', 'Review Date': '2024-04-07'}
# seat spacing is less
# The flight went from Terminal 1, the terminal with limited amenities. I was handed a voucher to a Sats lounge that was overfilled in terminal 1. The gate was chaos, under-dimensioned for the flight with 1 security screening. When I arrived the queue was >50m with a wait of about 20min. While service and entertainment in Economy is as good as one can expect from Singapore Airlines, seat spacing is less than in  other airlines.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Singapore to Hong Kong', 'Class': 'Business Class', 'Month Flown': '2024-01-01', 'Review Date': '2024-03-31'}
# service was efficient and friendly
# SQ894 is the afternoon flight to HKG operated by the A350. It was during the Lunar New Year period. On the menu was the traditional Yu Sheng or raw fish salad popular in Singapore and Malaysia during Lunar New Year. I booked the cook and had lobster thermidor as my main course. For a 3.5 hour flight the service was efficient and friendly. On this A350, the seat back needs to be flipped over to convert into bed mode but it wasn’t necessary on this short flight. Wifi connectivity was good.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Munich to Singapore', 'Class': 'Business Class', 'Month Flown': '2024-03-01', 'Review Date': '2024-03-31'}
# “Very disappointed”
# Very disappointed with Singapore Airlines. Dated and uncomfortable old seat in business class combined with below average food. Ok cabin crews. Last but not least they lost my bag. I would fly SQ again on short haul on a discount economy class ticket…
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Couple Leisure', 'Route': 'Singapore to Male', 'Class': 'Business Class', 'Month Flown': '2024-03-01', 'Review Date': '2024-03-30'}
# incompetent customer service
# I was flying business class from BCN to MLE via SIN. The flight with SQ was just a big hassle all the way through. The night before the BCN departure I was informed via SMS that the flight from BCN to SIN would be delayed by more that 3 hours. That was it. SQ could not have cared less about re-booking the flight proactively so that I would not miss my MLE connection in SIN. I had to call their incompetent customer service in Singapore and fight with them for 2 hours on the phone so that my flight was eventually rebooked via MUC - FOn the re-booked leg they managed to lose my bag in MUC. I did trace the bag with an Apple air tag and it was delivered to SIN the next day. Rather than getting the bag on the next flight to MLE, SQ kept it in SIN for another two days before sending it on to MLE From my experience, SQ is ok as it comes to cabin service (whilst you can see their cost saving actions as well with no more amenity kits in C, cheap wines etc.). However, as it comes to customer service, SQ is absolutely below any standard I have ever seen. In fact they could not care less about their customer - and I am speaking of business class.
# {'Airline': 'Singapore Airlines', 'Type of Traveller': 'Solo Leisure', 'Route': 'Singapore to Phuket', 'Class': 'Economy Class', 'Month Flown': '2024-03-01', 'Review Date': '2024-03-28'}
# not be flying Singapore Airlines again
# Singapore Airlines continues to enjoy a good reputation, however my most recent experience was very poor and fell far short of my expectations. Due to a cancellation by another airline, I needed to modify the departure on my full fare, refundable ticket. I completed the customer assistance form on their website to request the rebooking, and tried repeatedly over an 8 hour period to reach their customer service number in the US. It was impossible to get past the recording and reach an agent over the phone. It was also not possible to make this change myself online. Upon arriving at Changi, I discovered that instead of changing my outbound flight as requested, Singapore Airlines cancelled my entire ticket. When I tried to rebook the flight, there was not a single open seat for the return over a two day period (Easter weekend). Agents at Changi were apologetic and tried to help, but with no seats available, there was little they could do. I have never before been unable to reach an airline representative, and this has certainly not been the case when I have tried multiple channels over an 8 hour time period. I am appalled by the lack of basic customer service extended to a passenger holding a Y fare ticket and Star Alliance Gold status. I would encourage any US-based traveler to avoid Singapore Airlines at all costs until they can bring their customer service up to a minimum level. I will not be flying Singapore Airlines again.

# %%
for r in index.as_retriever().retrieve("What does Singapore Airlines offer?"):
    print(r.text)
# Out:
# Due to a cancellation by another airline, I needed to modify the departure on my full fare, refundable ticket. I completed the customer assistance form on their website to request the rebooking, and tried repeatedly over an 8 hour period to reach their customer service number in the US. It was impossible to get past the recording and reach an agent over the phone. It was also not possible to make this change myself online. Upon arriving at Changi, I discovered that instead of changing my outbound flight as requested, Singapore Airlines cancelled my entire ticket. When I tried to rebook the flight, there was not a single open seat for the return over a two day period (Easter weekend). Agents at Changi were apologetic and tried to help, but with no seats available, there was little they could do. I have never before been unable to reach an airline representative, and this has certainly not been the case when I have tried multiple channels over an 8 hour time period.
# That was it. SQ could not have cared less about re-booking the flight proactively so that I would not miss my MLE connection in SIN. I had to call their incompetent customer service in Singapore and fight with them for 2 hours on the phone so that my flight was eventually rebooked via MUC - FOn the re-booked leg they managed to lose my bag in MUC. I did trace the bag with an Apple air tag and it was delivered to SIN the next day. Rather than getting the bag on the next flight to MLE, SQ kept it in SIN for another two days before sending it on to MLE From my experience, SQ is ok as it comes to cabin service (whilst you can see their cost saving actions as well with no more amenity kits in C, cheap wines etc.). However, as it comes to customer service, SQ is absolutely below any standard I have ever seen. In fact they could not care less about their customer - and I am speaking of business class.
# This particular flight was booked via our company travel agent, a large international agent. Leaving aside the drop in service quality over years, from discontinuing warm towels to not offering snacks anymore during the flight, what has really infuriated me with SIA are the change policies. On this flight, despite having the highest premium economy booking class (T) with a full flexi ticket, a simple change in flight date cost me >1000$ extra is unexplained fees: In addition to the change in ticket price, which makes no sense on the highest booking class, a rebooking fee, a no show fee , a digital processing fee and the worst 250$ of "offline" fee because I used an agent, not their website. While my agent was helpful, SIA straight out refused to talk to them. It took 3 full days and 15 chat sessions to actually get the ticket rebooked for a simple day change on the exact same flight, SIA let them wait 30min per session, as they are only available to agents during Singapore business hours - and if they are closes they simply hang up.
# The following are knowledge sequence in max depth 2 in the form of directed graph like:
# `subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...`
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Has}]-> Service and entertainment good{name: Service and entertainment good}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Try}]-> Reach customer service number{name: Reach customer service number}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Have}]-> Star alliance gold status{name: Star alliance gold status}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Have}]-> Customer assistance form{name: Customer assistance form}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Handed}]-> Voucher to sats lounge{name: Voucher to sats lounge}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Let}]-> Wait 30min per session{name: Wait 30min per session}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} <-[relationship:{relationship: Should avoid}]- Us-based traveler{name: Us-based traveler}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} <-[relationship:{relationship: Is review date of}]- 2024-04-21{name: 2024-04-21}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Bring}]-> Customer service{name: Customer service}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Member of}]-> Krisflyer gold{name: Krisflyer gold}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Class}]-> Premium economy{name: Premium economy}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Discontinuing}]-> Warm towels{name: Warm towels}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Provides}]-> Inflight wifi{name: Inflight wifi}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Costs}]-> North of 1000${name: North of 1000$}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Class}]-> Business class{name: Business class}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Disappointed with}]-> Reviewer{name: Reviewer}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Cancel}]-> Entire ticket{name: Entire ticket}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Month flown}]-> 2024-04-01{name: 2024-04-01}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Review date}]-> 2024-03-30{name: 2024-03-30}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Month flown}]-> 2024-02-01{name: 2024-02-01}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Disappointed from}]-> Overall{name: Overall}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Month flown}]-> 2024-03-01{name: 2024-03-01}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Offers}]-> Warm towels{name: Warm towels}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Hang up}]-> If closes{name: If closes}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Type of}]-> Business{name: Business}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Have}]-> Open seat{name: Open seat}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Be}]-> Apologetic{name: Apologetic}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Founded in}]-> 1982{name: 1982}
# Singapore{name: Singapore} <-[relationship:{relationship: Founded in}]- Singapore airlines{name: Singapore airlines} -[relationship:{relationship: Gate}]-> Chaos{name: Chaos}
# Singapore{name: Singapore} <-[relationship:{relationship: To}]- Kochi{name: Kochi}

# %%
response = index.as_query_engine().query("Tell me about Singapore Airlines")
print(response)
# Out:
# Singapore Airlines, founded in 1982, is known for its high service standards and quality entertainment offerings. It provides various services such as customer assistance forms, access to Star Alliance Gold status, and amenities like inflight WiFi. The airline has faced criticism for its customer service in handling flight changes and cancellations, as well as for its change policies that include additional fees for simple modifications. Despite these issues, Singapore Airlines is recognized for its cabin service quality, although cost-saving measures like discontinuing amenity kits in certain classes have been noted.

# %%
response = index.as_query_engine().query("Tell me about Singapore Airlines")
print(response)

# %% [markdown]
# Doesnt seem to be from the KG...

# %%
from llama_index.core.query_engine import KnowledgeGraphQueryEngine


nl2kg_query_engine = KnowledgeGraphQueryEngine(
    storage_context=storage_context,
    service_context=service_context,
    llm=llm,
)
